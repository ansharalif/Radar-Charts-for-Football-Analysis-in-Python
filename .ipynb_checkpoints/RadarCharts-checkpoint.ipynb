# %%
import pandas as pd
import matplotlib.pyplot as plt
from soccerplots.radar_chart import Radar

# %%
#Reading the data
df = pd.read_csv("Data\eplplayershooting2122v2.csv")

# %%
df.head()
# Out:
#    Rk           Player   Nation Pos            Squad  Age  Born   90s   Gls  \
# 0   1       Max Aarons  eng ENG  DF     Norwich City   21  2000  32.0  0.00
# 1   2        Che Adams  sct SCO  FW      Southampton   25  1996  22.7  0.31
# 2   3  Rayan Aït Nouri   fr FRA  DF           Wolves   20  2001  20.3  0.05
# 3   4  Kristoffer Ajer   no NOR  DF        Brentford   23  1998  22.2  0.05
# 4   5       Nathan Aké   nl NED  DF  Manchester City   26  1995  10.3  0.19
#
#      Sh  ...   FK   PK  PKatt    xG  npxG  npxG/Sh  G-xG  np:G-xG  Matches  \
# 0  0.41  ...  0.0  0.0    0.0  0.02  0.02     0.05 -0.02    -0.02  Matches
# 1  2.16  ...  0.0  0.0    0.0  0.31  0.31     0.14 -0.00    -0.00  Matches
# 2  0.64  ...  0.0  0.0    0.0  0.03  0.03     0.06  0.01     0.01  Matches
# 3  0.32  ...  0.0  0.0    0.0  0.04  0.04     0.11  0.01     0.01  Matches
# 4  0.49  ...  0.0  0.0    0.0  0.11  0.11     0.23  0.09     0.09  Matches
#
#       -9999
# 0  774cf58b
# 1  f2bf1b0f
# 2  9b398aea
# 3  a8c0acb7
# 4  eaeca114
#
# [5 rows x 27 columns]

# %%
df.Player.unique()
# Out:
# array(['Max Aarons', 'Che Adams', 'Rayan Aït Nouri', 'Kristoffer Ajer',
#        'Nathan Aké', 'Marc Albrighton', 'Thiago Alcántara',
#        'Trent Alexander-Arnold', 'Alisson', 'Allan', 'Dele Alli',
#        'Miguel Almirón', 'Marcos Alonso', 'Steven Alzate',
#        'Daniel Amartey', 'Joachim Andersen', 'Michail Antonio',
#        'Cameron Archer', 'Alphonse Areola', 'Adam Armstrong',
#        'Stuart Armstrong', 'Kepa Arrizabalaga', 'Harrison Ashby',
#        'Pierre-Emerick Aubameyang', 'Jordan Ayew', 'Luke Ayling',
#        'César Azpilicueta', 'Daniel Bachmann', 'Leon Bailey',
#        'Eric Bailly', 'Folarin Balogun', 'Patrick Bamford',
#        'Shandon Baptiste', 'Ross Barkley', 'Ashley Barnes',
#        'Harvey Barnes', 'Lewis Bate', 'Mads Bech Sørensen',
#        'Jan Bednarek', 'Donny van de Beek', 'Asmir Begović',
#        'Saïd Benrahma', 'Rodrigo Bentancur', 'Christian Benteke',
#        'Jóhann Berg Guðmundsson', 'Steven Bergwijn', 'Ryan Bertrand',
#        'Mads Bidstrup', 'Yves Bissouma', 'Willy Boly', 'Jarrod Bowen',
#        'Jarrad Branthwaite', 'Armando Broja', 'Josh Brownhill',
#        'Lewis Brunt', 'Bryan', 'Emi Buendía', 'Dan Burn', 'Jack Butland',
#        'Sam Byram', 'Willy Caballero', 'Moisés Caicedo',
#        'Dominic Calvert-Lewin', 'Chem Campbell', 'João Cancelo',
#        'Sergi Canós', 'Todd Cantwell', 'Matty Cash', 'Timothy Castagne',
#        'Jonny Castro', 'Craig Cathcart', 'Edinson Cavani', 'Kayky Chagas',
#        'Trevoh Chalobah', 'Calum Chambers', 'Daniel Chesters',
#        'Ben Chilwell', 'Chiquinho', 'Hamza Choudhury',
#        'Andreas Christensen', 'Carney Chukwuemeka', 'Ciaran Clark',
#        'Tom Cleverley', 'Nathaniel Clyne', 'Conor Coady',
#        'Séamus Coleman', 'Nathan Collins', 'Aaron Connolly',
#        'Liam Cooper', 'Jack Cork', 'Maxwel Cornet', 'Hélder Costa',
#        'Vladimír Coufal', 'Philippe Coutinho', 'Aaron Cresswell',
#        'Charlie Cresswell', 'Cucho', 'Marc Cucurella', 'Luke Cundle',
#        'Patson Daka', 'Stuart Dallas', 'Diogo Dalot', 'Karl Darlow',
#        'Josh Dasilva', 'Ben Davies', 'Tom Davies', 'Keinan Davis',
#        'Craig Dawson', 'Kevin De Bruyne', 'Troy Deeney', 'Liam Delap',
#        'Fabian Delph', 'Leander Dendoncker', 'Emmanuel Dennis',
#        'Kiernan Dewsbury Hall', 'Ibrahima Diallo', 'Raphael Dias Belloli',
#        'Rúben Dias', 'Luis Díaz', 'Eric Dier', 'Lucas Digne',
#        'Virgil van Dijk', 'Issa Diop', 'Moussa Djenepo', 'Lewis Dobbin',
#        'Matt Doherty', 'Gabriel Dos Santos', 'Abdoulaye Doucouré',
#        'Kieran Dowell', 'Cody Drameh', 'Martin Dúbravka', 'Shane Duffy',
#        'Paul Dummett', 'Lewis Dunk', 'Ederson', 'Odsonne Édouard',
#        'CJ Egan-Riley', 'Anthony Elanga', 'Harvey Elliott',
#        'Mohamed Elneny', 'Mohamed Elyounoussi', 'Emerson',
#        'Christian Eriksen', 'Oghenekaro Etebo', 'Jonny Evans',
#        'Eberechi Eze', 'Łukasz Fabiański', 'Fabinho', 'Kiko Femenía',
#        'Evan Ferguson', 'Nathan Ferguson', 'Bruno Fernandes',
#        'Álvaro Fernández', 'Federico Fernández', 'Fernandinho',
#        'Roberto Firmino', 'Junior Firpo', 'Ashley Fletcher', 'Phil Foden',
#        'Wesley Fofana', 'Pablo Fornals', 'Adam Forshaw', 'Marcus Forss',
#        'Fraser Forster', 'Ben Foster', 'Tariqe Fosu', 'Ryan Fraser',
#        'Fred', 'Ryan Fredericks', 'Leo Fuhr Hjelde', 'Conor Gallagher',
#        'Alejandro Garnacho', 'Dwight Gayle', 'Jean-Philippe Gbamin',
#        'David de Gea', 'Joe Gelhardt', 'Anwar El Ghazi', 'Saman Ghoddos',
#        'Dimitris Giannoulis', 'Morgan Gibbs-White', 'Ben Gibson',
#        'Billy Gilmour', 'Ben Godfrey', 'André Gomes', 'Toti Gomes',
#        'Joe Gomez', 'Charlie Goode', 'Anthony Gordon', 'Kaide Gordon',
#        'Dan Gosling', 'Demarai Gray', 'Jack Grealish', 'Mason Greenwood',
#        'Sam Greenwood', 'Pascal Groß', 'Vicente Guaita', 'Marc Guéhi',
#        'Bruno Guimarães', 'İlkay Gündoğan', 'Angus Gunn', 'Grant Hanley',
#        'Jack Harrison', 'Kortney Hause', 'Kai Havertz', 'Isaac Hayden',
#        'Hwang Hee-chan', 'Jordan Henderson', 'Jeff Hendrick',
#        'Wayne Hennessey', 'Rico Henry', 'Son Heung-min', 'Ki-Jana Hoever',
#        'Rob Holding', 'Mason Holgate', 'Callum Hudson-Odoi',
#        'Will Hughes', 'Pierre Højbjerg', 'Adam Idah', 'Kelechi Iheanacho',
#        'Danny Ings', 'Tim Iroegbunam', 'Alex Iwobi', 'Daniel James',
#        'Reece James', 'Vitaly Janelt', 'Pontus Jansson', 'Mathias Jensen',
#        'Gabriel Jesus', 'Raúl Jiménez', 'Joelinton', 'Ben Johnson',
#        'Curtis Jones', 'Phil Jones', 'Jorginho', 'Diogo Jota',
#        'James Justin', 'Mathias Jørgensen', 'Ozan Kabak',
#        'Christian Kabasele', 'Samuel Kalu', 'Hassane Kamara',
#        'Harry Kane', "N'Golo Kanté", 'Edo Kayembe', 'Moise Kean',
#        'Michael Keane', 'Naby Keïta', 'Caoimhín Kelleher', 'Kenedy',
#        'Jonjoe Kenny', 'Max Kilman', 'Joshua King', 'Kristoffer Klaesson',
#        'Mateusz Klich', 'Robin Koch', 'Sead Kolašinac', 'Ibrahima Konaté',
#        'Ezri Konsa', 'Cheikhou Kouyaté', 'Mateo Kovačić', 'Emil Krafth',
#        'Alex Král', 'Tim Krul', 'Juraj Kucka', 'Dejan Kulusevski',
#        'Alexandre Lacazette', 'Adam Lallana', 'Tariq Lamptey',
#        'Manuel Lanzini', 'Aymeric Laporte', 'Jamaal Lascelles',
#        'Pierre Lees-Melou', 'Aaron Lennon', 'Bernd Leno', 'Jamal Lewis',
#        'Victor Lindelöf', 'Jesse Lingard', 'Valentino Livramento',
#        'Diego Llorente', 'Hugo Lloris', 'Giovani Lo Celso',
#        'Jürgen Locadia', 'Ruben Loftus-Cheek', 'Kevin Long', 'Shane Long',
#        'Sean Longstaff', 'Ademola Lookman', 'Jonas Lössl', 'Imran Louza',
#        'Matthew Lowton', 'Douglas Luiz', 'Romelu Lukaku', 'Lyanco',
#        'Alexis Mac Allister', 'James Maddison', 'Harry Maguire',
#        'Riyad Mahrez', 'Ainsley Maitland-Niles', 'Sadio Mané',
#        'Javier Manquillo', 'Fernando Marçal', 'Solly March', 'Pablo Marí',
#        'Anthony Martial', 'Martinelli', 'Emiliano Martínez',
#        'Adam Masina', 'Arthur Masuaku', 'Juan Mata',
#        'Jean-Philippe Mateta', 'Nemanja Matić', 'Joël Matip',
#        'Neal Maupay', 'Bryan Mbeumo', 'James McArthur', 'James Mcatee',
#        'Kasey McAteer', 'Liam McCarron', 'Alex McCarthy', 'John McGinn',
#        'Stuart McKinstry', 'Kenny McLean', 'Dwight McNeil',
#        'Scott McTominay', 'Ben Mee', 'Hannibal Mejbri', 'Benjamin Mendy',
#        'Edouard Mendy', 'Nampalys Mendy', 'Illan Meslier',
#        'Luka Milivojević', 'James Milner', 'Yerry Mina',
#        'Takumi Minamino', 'Tyrone Mings', 'Tyrick Mitchell',
#        'Jakub Moder', 'Wesley Moraes', 'Tyler Morton', 'Mason Mount',
#        'Lucas Moura', 'João Moutinho', 'Bali Mumba', 'Jacob Murphy',
#        'Enock Mwepu', 'Vitaliy Mykolenko', 'Marvelous Nakamba',
#        'Wilfred Ndidi', 'Tanguy Ndombele', 'Reiss Nelson', 'Pedro Neto',
#        'Rúben Neves', 'Jeremy Ngakia', 'Saúl Ñíguez', 'Eddie Nketiah',
#        'Nicolas Nkoulou', 'Mark Noble', 'Mathias Normann',
#        'Christian Nørgaard', 'Angelo Ogbonna', 'Michael Olise',
#        'Robin Olsen', 'Andrew Omobamidele', 'Tyler Onyango',
#        'Frank Onyeka', 'Divock Origi', 'Alex Oxlade-Chamberlain',
#        'Cole Palmer', 'Emerson Palmieri', 'Thomas Partey', 'João Pedro',
#        'Nicolas Pépé', 'Ricardo Pereira', 'Ayoze Pérez', 'Sonny Perkins',
#        'Romain Perraud', 'Kalvin Phillips', 'Jaden Philogene Bidace',
#        'Jordan Pickford', 'Erik Pieters', 'Ethan Pinnock',
#        'Daniel Podence', 'Paul Pogba', 'Nick Pope', 'Isaac Price',
#        'Teemu Pukki', 'Christian Pulisic', 'Przemysław Płacheta',
#        'Jesuran Rak Sakyi', 'Aaron Ramsdale', 'Jacob Ramsey',
#        'Marcus Rashford', 'Milot Rashica', 'David Raya', 'Nathan Redmond',
#        'Sergio Reguilón', 'Declan Rice', 'Taylor Richards', 'Richarlison',
#        'Jaïro Riedewald', 'Matt Ritchie', 'Connor Roberts',
#        'Tyler Roberts', 'Andrew Robertson', 'Joe Rodon', 'Rodri',
#        'Rodrigo', 'Jay Rodriguez', 'Mads Roerslev', 'Cristian Romero',
#        'Oriol Romeu', 'Cristiano Ronaldo', 'Salomón Rondón', 'Danny Rose',
#        'Jon Rowe', 'John Ruddy', 'Antonio Rüdiger', 'Lukas Rupp',
#        'José Sá', 'Allan Saint-Maximin', 'Romain Saïss', 'Bukayo Saka',
#        'Mohamed Salah', 'Mohammed Salisu', 'Albert Sambi Lokonga',
#        'Davinson Sánchez', 'Robert Sánchez', 'Jadon Sancho',
#        'Morgan Sanson', 'Samir Santos', 'Josh Sargent',
#        'Jeremy Sarmiento', 'Ismaila Sarr', 'Malang Sarr', 'Dane Scarlett',
#        'Fabian Schär', 'Jeffrey Schlupp', 'Kasper Schmeichel', 'Ken Sema',
#        'Nélson Semedo', 'Ryan Sessegnon', 'Jamie Shackleton', 'Luke Shaw',
#        'Jonjo Shelvey', 'Shola Shoretire', 'Francisco Sierralta',
#        'Bernardo Silva', 'Fábio Silva', 'Thiago Silva', 'Ellis Simms',
#        'Moussa Sissoko', 'Oliver Skipp', 'William Smallbone',
#        'Emile Smith Rowe', 'Cédric Soares', 'Tomáš Souček',
#        'Boubakary Soumaré', 'Çağlar Söyüncü', 'Tony Springett',
#        'Jason Steele', 'Jed Steer', 'Zack Steffen', 'Dale Stephens',
#        'Jack Stephens', 'Raheem Sterling', 'Finley Stevens',
#        'John Stones', 'Pascal Struijk', 'Crysencio Summerville',
#        'Jakob Sørensen', 'Japhet Tanganga', 'Matt Targett',
#        'James Tarkowski', 'Nuno Tavares', 'Charlie Taylor',
#        'Nathan Tella', 'Alex Telles', 'Luke Thomas', 'Dominic Thompson',
#        'Youri Tielemans', 'Kieran Tierney', 'Takehiro Tomiyasu',
#        'James Tomkins', 'Ivan Toney', 'Ferrán Torres', 'Cenk Tosun',
#        'Andros Townsend', 'Adama Traoré', 'Bertrand Traoré', 'Trézéguet',
#        'Francisco Trincão', 'Kieran Trippier', 'William Troost-Ekong',
#        'Leandro Trossard', 'Kostas Tsimikas', 'Axel Tuanzebe',
#        'Ozan Tufan', 'Christos Tzolis', 'Yan Valery', 'Raphaël Varane',
#        'Jamie Vardy', 'Joël Veltman', 'Jannik Vestergaard',
#        'Nikola Vlašić', 'Matěj Vydra', 'Theo Walcott', 'Kyle Walker',
#        'Kyle Walker-Peters', 'Aaron Wan-Bissaka', 'Danny Ward',
#        'Joel Ward', 'James Ward-Prowse', 'Ollie Watkins', 'Adam Webster',
#        'Wout Weghorst', 'Danny Welbeck', 'Timo Werner', 'Ashley Westwood',
#        'Ben White', 'Brandon Williams', 'Neco Williams', 'Joe Willock',
#        'Callum Wilson', 'Harry Winks', 'Yoane Wissa', 'Chris Wood',
#        'Freddie Woodman', 'Granit Xhaka', 'Andriy Yarmolenko',
#        'Ashley Young', 'Nathan Young-Coombes', 'Wilfried Zaha',
#        'Christoph Zimmermann', 'Oleksandr Zinchenko', 'Hakim Ziyech',
#        'Kurt Zouma', 'Martin Ødegaard'], dtype=object)

# %%
df = df[(df["Player"]=="Mohamed Salah") | (df["Player"]=="Son Heung-min")].reset_index()

# %%
df
# Out:
#    index   Rk         Player  Nation   Pos      Squad  Age  Born   90s   Gls  \
# 0    216  217  Son Heung-min  kr KOR  FWMF  Tottenham   29  1992  33.4  0.69
# 1    429  430  Mohamed Salah  eg EGY    FW  Liverpool   29  1992  30.7  0.75
#
#    ...    FK    PK  PKatt    xG  npxG  npxG/Sh  G-xG  np:G-xG  Matches  \
# 0  ...  0.06  0.00    0.0  0.49  0.49     0.19  0.20     0.20  Matches
# 1  ...  0.03  0.16    0.2  0.71  0.55     0.13  0.04     0.03  Matches
#
#       -9999
# 0  92e7e919
# 1  e342ad68
#
# [2 rows x 28 columns]

# %%
df.dtypes
# Out:
# index        int64
# Rk           int64
# Player      object
# Nation      object
# Pos         object
# Squad       object
# Age          int64
# Born         int64
# 90s        float64
# Gls        float64
# Sh         float64
# SoT        float64
# SoT%       float64
# Sh/90      float64
# SoT/90     float64
# G/Sh       float64
# G/SoT      float64
# Dist       float64
# FK         float64
# PK         float64
# PKatt      float64
# xG         float64
# npxG       float64
# npxG/Sh    float64
# G-xG       float64
# np:G-xG    float64
# Matches     object
# -9999       object
# dtype: object

# %%
df = df.drop(["index", "Rk", "Nation", "Pos", "Squad", "Age", "Born", "90s", "FK", "PK", "PKatt","Matches","G-xG","np:G-xG","-9999"],axis=1)

# %%
df
# Out:
#           Player   Gls    Sh   SoT  SoT%  Sh/90  SoT/90  G/Sh  G/SoT  Dist  \
# 0  Son Heung-min  0.69  2.57  1.41  54.7   2.57    1.41  0.27   0.49  15.4
# 1  Mohamed Salah  0.75  4.36  1.60  36.6   4.37    1.60  0.13   0.37  15.5
#
#      xG  npxG  npxG/Sh
# 0  0.49  0.49     0.19
# 1  0.71  0.55     0.13

# %%
#Get paramaters
params = list(df.columns)
params = params[1:]
params
# Out:
# ['Gls',
#  'Sh',
#  'SoT',
#  'SoT%',
#  'Sh/90',
#  'SoT/90',
#  'G/Sh',
#  'G/SoT',
#  'Dist',
#  'xG',
#  'npxG',
#  'npxG/Sh']

# %%
#Add ranges to list of tuple pairs
ranges = []
son_values = []
salah_values = []

for x in params:
    a = min(df[params][x])
    a = a - (a*.2)
    
    b = min(df[params][x])
    b = b + (b*.5)

    ranges.append((a,b))

for x in range(len(df["Player"])):
    if df["Player"][x] == "Son Heung-min":
        son_values = df.iloc[x].values.tolist()
    if df["Player"][x] == "Mohamed Salah":
        salah_values = df.iloc[x].values.tolist()
        
son_values = son_values[1:]
salah_values = salah_values[1:]

values = [son_values, salah_values]

# %%
values
# Out:
# [[0.69, 2.57, 1.41, 54.7, 2.57, 1.41, 0.27, 0.49, 15.4, 0.49, 0.49, 0.19],
#  [0.75, 4.36, 1.6, 36.6, 4.37, 1.6, 0.13, 0.37, 15.5, 0.71, 0.55, 0.13]]

# %%
salah_values
# Out:
# [0.75, 4.36, 1.6, 36.6, 4.37, 1.6, 0.13, 0.37, 15.5, 0.71, 0.55, 0.13]

# %%
#Title
title = dict(
    title_name = "Son Heung-min",
    title_color = "#172043",
    subtitle_name = "Tottenham",
    subtitle_color = "#172043",
    title_name_2 = "Mohamed Salah",
    title_color_2 = "#dd202e",
    subtitle_name_2 = "Liverpool",
    subtitle_color_2 = "#dd202e",
    title_fontsize = 18,
    subtitle_fontsize = 15
)
endnote = '@ansharalif\nData collected from FBREF / Statsbomb'

# %%
radar = Radar()

fig,ax = radar.plot_radar(ranges = ranges, params = params, values = values, radar_color = ["#172043", "#dd202e"],
                         alphas = [0.5,0.55], title = title, endnote = endnote, compare = True)
